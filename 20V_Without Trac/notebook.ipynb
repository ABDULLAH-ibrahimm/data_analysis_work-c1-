# %% [markdown]
# # Install and Import Libraries

# %%
# !pip install pandas matplotlib seaborn lxml numpy
# Out:
# Requirement already satisfied: pandas in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: lxml in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (5.3.0)
# Requirement already satisfied: numpy in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\abdo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\Abdo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Import necessary libraries
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configure visualizations for better aesthetics
sns.set(style="whitegrid")

# %% [markdown]
# # Data Extraction

# %%
# Load and parse the XML file
file_path = 'tripinfo20 withouttraci.xml'
tree = ET.parse(file_path)
root = tree.getroot()

# %%
# Extract all available columns from <tripinfo> into a list of dictionaries
data = []
for trip in root.findall('tripinfo'):
    data.append({
        'id': trip.get('id'),
        'depart': float(trip.get('depart')),
        'arrival': float(trip.get('arrival')),
        'duration': float(trip.get('duration')),
        'routeLength': float(trip.get('routeLength')),
        'waitingTime': float(trip.get('waitingTime')),
        'timeLoss': float(trip.get('timeLoss')),
        'departLane': trip.get('departLane'),
        'arrivalLane': trip.get('arrivalLane'),
        'devices': trip.get('devices'),
        'vType': trip.get('vType'),
        'rerouteNo': int(trip.get('rerouteNo')) if trip.get('rerouteNo') else np.nan,
        'departSpeed': float(trip.get('departSpeed')) if trip.get('departSpeed') else np.nan,
        'arrivalSpeed': float(trip.get('arrivalSpeed')) if trip.get('arrivalSpeed') else np.nan,
    })

# Convert list of dictionaries to a DataFrame
df = pd.DataFrame(data)

# Preview the extracted data
print("Extracted Data Preview:")
df
# Out:
# Extracted Data Preview:
#              id  depart  arrival  duration  routeLength  waitingTime  \
# 0        veh140    44.0     82.0      38.0       410.67          0.0
# 1         veh39    13.0    133.0     120.0      1213.41          1.0
# 2         veh50    16.0    136.0     120.0      1049.33          0.0
# 3         veh20     7.0    148.0     141.0      1815.08          0.0
# 4         veh78    25.0    157.0     132.0       967.77         20.0
# ...         ...     ...      ...       ...          ...          ...
# 7278    veh8331  2567.0   4985.0    2418.0     10064.58       1256.0
# 7279  truck7646  3534.0   4990.0    1456.0     13883.76        254.0
# 7280    veh9565  2947.0   4991.0    2044.0      9734.43       1044.0
# 7281   veh11135  3431.0   4991.0    1560.0      4784.33        920.0
# 7282    veh6893  2124.0   4996.0    2872.0      5171.98       2133.0
#
#       timeLoss     departLane    arrivalLane  \
# 0         5.14  239353258#1_0   7546429#11_0
# 1        17.95   7516981#12_0   7515979#16_0
# 2        13.66    7331866#0_0  430014571#0_0
# 3        17.99    7332973#3_0   27628545#1_0
# 4        40.31   -7511797#9_0   -7511774#9_0
# ...        ...            ...            ...
# 7278   1673.99   -7546406#2_0   -7333384#5_0
# 7279    552.51      7546296_0   -7546463#0_0
# 7280   1259.66  389372138#0_0    7546966#0_0
# 7281   1100.49      7332739_0      7332806_0
# 7282   2419.91    7333348#7_0   -7331892#1_0
#
#                                    devices          vType  rerouteNo  \
# 0           tripinfo_veh140 routing_veh140  veh_passenger          1
# 1             tripinfo_veh39 routing_veh39  veh_passenger          1
# 2             tripinfo_veh50 routing_veh50  veh_passenger          1
# 3             tripinfo_veh20 routing_veh20  veh_passenger          1
# 4             tripinfo_veh78 routing_veh78  veh_passenger          1
# ...                                    ...            ...        ...
# 7278      tripinfo_veh8331 routing_veh8331  veh_passenger          1
# 7279  tripinfo_truck7646 routing_truck7646    truck_truck          1
# 7280      tripinfo_veh9565 routing_veh9565  veh_passenger          1
# 7281    tripinfo_veh11135 routing_veh11135  veh_passenger          1
# 7282      tripinfo_veh6893 routing_veh6893  veh_passenger          1
#
#       departSpeed  arrivalSpeed
# 0            0.00         12.43
# 1            0.00          8.79
# 2            7.30         11.87
# 3            0.00         13.87
# 4            0.00          7.74
# ...           ...           ...
# 7278         0.00          6.85
# 7279         7.72          3.84
# 7280         7.25          6.01
# 7281         8.55          7.32
# 7282         0.00          7.97
#
# [7283 rows x 14 columns]

# %% [markdown]
# # Data cleaning

# %% [markdown]
# - 1 | Remove Unnecessary Columns

# %%
columns_to_drop = ['id','departLane', 'arrivalLane', 'devices']
df_cleaned = df.drop(columns=columns_to_drop, axis=1)

# Confirm remaining columns
print("Remaining Columns After Dropping Unnecessary Ones:")
df_cleaned
# Out:
# Remaining Columns After Dropping Unnecessary Ones:
#       depart  arrival  duration  routeLength  waitingTime  timeLoss  \
# 0       44.0     82.0      38.0       410.67          0.0      5.14
# 1       13.0    133.0     120.0      1213.41          1.0     17.95
# 2       16.0    136.0     120.0      1049.33          0.0     13.66
# 3        7.0    148.0     141.0      1815.08          0.0     17.99
# 4       25.0    157.0     132.0       967.77         20.0     40.31
# ...      ...      ...       ...          ...          ...       ...
# 7278  2567.0   4985.0    2418.0     10064.58       1256.0   1673.99
# 7279  3534.0   4990.0    1456.0     13883.76        254.0    552.51
# 7280  2947.0   4991.0    2044.0      9734.43       1044.0   1259.66
# 7281  3431.0   4991.0    1560.0      4784.33        920.0   1100.49
# 7282  2124.0   4996.0    2872.0      5171.98       2133.0   2419.91
#
#               vType  rerouteNo  departSpeed  arrivalSpeed
# 0     veh_passenger          1         0.00         12.43
# 1     veh_passenger          1         0.00          8.79
# 2     veh_passenger          1         7.30         11.87
# 3     veh_passenger          1         0.00         13.87
# 4     veh_passenger          1         0.00          7.74
# ...             ...        ...          ...           ...
# 7278  veh_passenger          1         0.00          6.85
# 7279    truck_truck          1         7.72          3.84
# 7280  veh_passenger          1         7.25          6.01
# 7281  veh_passenger          1         8.55          7.32
# 7282  veh_passenger          1         0.00          7.97
#
# [7283 rows x 10 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7283 entries, 0 to 7282
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   depart        7283 non-null   float64
#  1   arrival       7283 non-null   float64
#  2   duration      7283 non-null   float64
#  3   routeLength   7283 non-null   float64
#  4   waitingTime   7283 non-null   float64
#  5   timeLoss      7283 non-null   float64
#  6   vType         7283 non-null   object
#  7   rerouteNo     7283 non-null   int64
#  8   departSpeed   7283 non-null   float64
#  9   arrivalSpeed  7283 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 569.1+ KB

# %%
df_cleaned.describe()
# Out:
#             depart      arrival     duration   routeLength  waitingTime  \
# count  7283.000000  7283.000000  7283.000000   7283.000000  7283.000000
# mean   1765.121653  2668.359467   903.237814   6236.808590   342.709048
# std     992.572228  1261.134676   660.898796   4320.184196   465.815998
# min       0.000000    82.000000    38.000000     33.570000     0.000000
# 25%    1181.000000  1656.500000   411.000000   2711.025000    32.000000
# 50%    1887.000000  2657.000000   734.000000   5472.700000   145.000000
# 75%    2443.500000  3684.000000  1232.500000   9177.035000   473.000000
# max    4581.000000  4996.000000  4829.000000  25939.850000  3678.000000
#
#           timeLoss    rerouteNo  departSpeed  arrivalSpeed
# count  7283.000000  7283.000000  7283.000000   7283.000000
# mean    493.217152     1.024852     1.350389      9.600762
# std     544.995980     0.216239     3.972069      4.207361
# min       3.140000     0.000000     0.000000      0.000000
# 25%     112.935000     1.000000     0.000000      7.440000
# 50%     275.570000     1.000000     0.000000      8.190000
# 75%     698.515000     1.000000     0.000000     12.060000
# max    3993.760000     9.000000    37.390000     32.860000

# %% [markdown]
# - 2 | Check for Missing Values

# %%
missing_values = df_cleaned.isnull().sum()
print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# depart          0
# arrival         0
# duration        0
# routeLength     0
# waitingTime     0
# timeLoss        0
# vType           0
# rerouteNo       0
# departSpeed     0
# arrivalSpeed    0
# dtype: int64

# %% [markdown]
# - 3 | Handle Missing Values
#     - here because null values are zero for this dont need handle missing value

# %%
# Fill missing values with median for numerical columns
#df_cleaned.fillna(df_cleaned.median(), inplace=True)

# Verify no missing values remain

#print("Missing Values After Cleaning:")
#print(df_cleaned.isnull().sum())

# %% [markdown]
# - 4  | Check for Duplicate Rows

# %%
# Check for duplicate rows
duplicates = df_cleaned.duplicated().sum()
print(f"Number of Duplicate Rows: {duplicates}")

# Drop duplicates if any
#df_cleaned = df_cleaned.drop_duplicates()
#print("Duplicates removed.")
# Out:
# Number of Duplicate Rows: 0

# %% [markdown]
# # Outlier Detection and Treatment

# %%
# Plot boxplots for all numeric columns (before treatment)
num_cols = df_cleaned.select_dtypes(include='number').columns
for col in num_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot( x=df_cleaned[col], color='orange')
    plt.title(f'Boxplot of {col} (Before Treatment)')
    plt.xlabel(col)
    plt.savefig(f'{col}_before_outlier_treatment.png')  # Save the plot as an image
    plt.show()

# %%
# Apply IQR method for outlier adjustment
for col in num_cols:
    q1 = df_cleaned[col].quantile(0.25)
    q3 = df_cleaned[col].quantile(0.75)
    iqr = q3 - q1

    # Define upper and lower bounds
    upper = q3 + (1.5 * iqr)
    lower = q1 - (1.5 * iqr)

    # Adjust outliers
    df_cleaned.loc[df_cleaned[col] > upper, col] = upper
    df_cleaned.loc[df_cleaned[col] < lower, col] = lower

    # Plot the boxplot for the column
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df_cleaned[col])
    plt.title(f'Boxplot of {col} (After Outlier Treatment)')
    plt.savefig(f'outliers of {col} after treat.png')
    plt.show()

# %% [markdown]
# # Visualization

# %% [markdown]
# - Heatmap of Correlations

# %%
# Generate a heatmap for correlation analysis
# Encode categorical column 'vType' using one-hot encoding
df_encoded = pd.get_dummies(df_cleaned, columns=['vType'], drop_first=True)

# Generate correlation matrix for numeric and encoded columns
correlation_matrix = df_encoded.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap with Encoded Categorical Data')
plt.show()

# %% [markdown]
# -  distributions for each numeric column

# %%
for col in num_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df_cleaned[col], kde=True, bins=30, color='blue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.savefig(F'distribution of {col}.png')
    plt.show()

# %% [markdown]
# # Save the Processed Data

# %%
# Save the cleaned and processed data to a CSV file
df_cleaned.to_csv('processed_tripinfo_20_withouttrac.csv', index=False)
print("Cleaned and processed data saved to 'processed_tripinfo_20_withouttrace.csv'.")
# Out:
# Cleaned and processed data saved to 'processed_tripinfo_20_withouttrace.csv'.
